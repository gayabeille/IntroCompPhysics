# %% [markdown]
# # PHYS 256 Midterm Exam - 10/12/2018
#
# <br><br>
# Name:\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_
#
# #### Useful equations
#
# \begin{equation}
#     f(x + \Delta x) = f(x) + \frac{\partial f(x)}{\partial x} \Delta x + \frac{1}{2} \frac{\partial^2 f(x)}{\partial x^2} (\Delta x)^2 + \ldots
# \end{equation}
#
# 1. (2 pts) What is subtractive cancellation error? Give an example where subtractive cancellation would provide an incorrect numerical result.
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# 2. Euler's method.
#     <ol type="a">
#     <li>(3 pts) Use the Taylor expansion to write a finite difference equation to iteratively solve a generic ordinary differential equation of the form
#     <br><br>
# \begin{equation}
#     \frac{d x(t)}{d t} = f(x,t)
# \end{equation}
#     </li>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <li>(2pts) Graphically illustrate how Euler's method approximates the solution to the ODE during each iteration</li>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <li>(5 pts) Write a pseudo-code (use python notation if desired, you will not be graded on syntax accuracy) that iteratively solves the radioactive decay differential equation
#     <br><br>
# \begin{equation}
#     \frac{dN(t)}{dt} = -\frac{N}{\tau},
# \end{equation}
#     <br><br>
#     where $N(t)$ is the number of undecayed nuclei at time $t$ and $\tau$ is the time decay constant. Solve the equation for some initial value of $N$ over some time interval from $0$ to $t_{\text{max}}$.
#     </li>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <li>(3 pts) Write the finite difference equations needed to use Euler's method to solve a second order differential equation as two coupled first order equations.
# \begin{equation}
#     \frac{d^2 x(t)}{d t^2} = g(x,t)
# \end{equation}
#     </li>
#     </ol>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
# 3. (2 pts) Write a pseudo-code that generates $N$ uniformly distributed random numbers between the values of -5 and 10 based on a random number generator that produces numbers between 0 and 1 such as `numpy.random.random()`.
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# 4. (3 pts) Explain in words or graphically what constitutes a chaotic system such as the chaotic pendulum.
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# 5. Random walkers.
# <ol type="a">
#     <li>(5 pts) A 1D random walker takes steps to the right or to the left at every iteration (it is not allowed to stay in place) with equal probability $P_{\text{right}} = P_{\text{left}} = \frac{1}{2}$, and the displacement at each iteration is always the same, $\Delta x = \pm a$. Write a pseudo-code for a function that takes as input the number of steps/iterations ($N$) and returns the position (i.e., the net displacement) of the walker at every step. Assume that $a=1$.
#     </li>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <li>(2 pts) On average, what is the net displacement, $\langle x \rangle$, and squared displacement, $\langle x^2 \rangle$, after taking a large number of steps?
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <li>(3 pts) <strong> Additional question for graduate students (extra credit for undergrads).</strong> Write a pseudo-code that extends the function created in part (A) to 2-dimensions ($x$ and $y$). Normalize the step size in $x$ and $y$ so that the net displacement after each step remains as $\pm a$.
#     </li>
#     </ol>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
# 6. The one-dimensional diffusion equation.
# <ol type="a">
#     <li>(5 pts) Use Taylor expansions in time, $t+\Delta t$, and space, $x \pm \Delta x$, to write a finite difference equation to iteratively solve the diffusion equation
#     <br><br>
# \begin{equation}
#     \frac{\partial \rho (x,t)}{\partial t} = D \frac{\partial^2 \rho (x,t)}{\partial x^2},
# \end{equation}
#     <br><br>
#     where $\rho (x,t)$ is the local concentration of particles at a point in time $t$ and position $x$, and $D$ is the diffusion coefficient of the particle of interest.
#     </li>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <li>(3 pts) <strong> Additional question for graduate students (extra credit for undergrads).</strong> Write a pseudo-code that solves the 1-dimensional diffusion equation for an initial set of conditions. Create a 1-dimensional array that will store the concentration of particles for every position and time. A simple initial condition ($t=0$) is a point source with a given concentration in the center of the grid ( $\rho (i_\text{center}, 0) = 1$ ) and 0 otherwise. A diffusion coefficient of $D = \text{1E-3}$ is appropriate for a spatial grid size of 100 ($\Delta x = 1/100$) and 1000 time iterations ($\Delta t = 1/1000$). Ignore any boundary conditions.
#     </li>
#     </ol>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
# 7. (2 pts) Explain in words or draw a sketch to explain the general principle of the Monte Carlo method used to find the area of an object ("throwing stones in a pond").
